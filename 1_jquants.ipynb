# %%
import requests
import json

data={"mailaddress":"katoshin@ruri.waseda.jp", "password":"mcjwVDTdPnKd7XP"}
r_post = requests.post("https://api.jquants.com/v1/token/auth_user", data=json.dumps(data))
rToken = r_post.json()["refreshToken"]

# %%
import pandas as pd

# %%
REFRESH_TOKEN = rToken
r_post = requests.post(f"https://api.jquants.com/v1/token/auth_refresh?refreshtoken={REFRESH_TOKEN}")
idToken = r_post.json()["idToken"]

# %%
# 上場銘柄一覧
headers = {'Authorization': 'Bearer {}'.format(idToken)}
r = requests.get("https://api.jquants.com/v1/listed/info", headers=headers)

# Pandas DafaFrameへ変換
r_dict = r.json()
df = pd.DataFrame(r_dict['info'])

# %%
df["MarketCodeCleansed"] = df[df["MarketCode"].isin(["0111", "0112"])]["Code"].str[:4] + ".T"

# %%
df.head()
# Out:
#          Date   Code                                        CompanyName  \
# 0  2024-04-26  13010                                                 極洋
# 1  2024-04-26  13050            大和アセットマネジメント株式会社　ｉＦｒｅｅＥＴＦ　ＴＯＰＩＸ（年１回決算型）
# 2  2024-04-26  13060           野村アセットマネジメント株式会社　ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ連動型上場投信
# 3  2024-04-26  13080                日興アセットマネジメント株式会社　　上場インデックスファンドＴＯＰＩＸ
# 4  2024-04-26  13090  野村アセットマネジメント株式会社　ＮＥＸＴ　ＦＵＮＤＳ　ＣｈｉｎａＡＭＣ・中国株式・上証５０...
#
#                                   CompanyNameEnglish Sector17Code  \
# 0                                   KYOKUYO CO.,LTD.            1
# 1              iFreeETF TOPIX (Yearly Dividend Type)           99
# 2              NEXT FUNDS TOPIX Exchange Traded Fund           99
# 3             Nikko Exchange Traded Index Fund TOPIX           99
# 4  NEXT FUNDS ChinaAMC SSE50 Index Exchange Trade...           99
#
#   Sector17CodeName Sector33Code Sector33CodeName  ScaleCategory MarketCode  \
# 0               食品         0050           水産・農林業  TOPIX Small 2       0111
# 1              その他         9999              その他              -       0109
# 2              その他         9999              その他              -       0109
# 3              その他         9999              その他              -       0109
# 4              その他         9999              その他              -       0109
#
#   MarketCodeName MarketCodeCleansed
# 0           プライム             1301.T
# 1            その他                NaN
# 2            その他                NaN
# 3            その他                NaN
# 4            その他                NaN

# %%
ticker = []

# %%
ticker = df[df["MarketCode"].isin(["0111", "0112"])]["MarketCodeCleansed"].values.tolist()

# %%
import yfinance as yf
import datetime as datetime

# 取得期間を指定
start = datetime.datetime(2024, 7, 10)
end = datetime.datetime(2024, 7, 11)

# 欲しい銘柄のティッカーを指定
stockList = ticker

# データを取得
df_yf = yf.download(stockList, start=start, end=end)
# Out:
# [****                   9%%                      ]  288 of 3260 completed
# $4185.T: possibly delisted; No price data found  (1d 2024-07-10 00:00:00 -> 2024-07-11 00:00:00)
# [*****                 10%%                      ]  326 of 3260 completed
# $7816.T: possibly delisted; No price data found  (1d 2024-07-10 00:00:00 -> 2024-07-11 00:00:00)
# [*****                 11%%                      ]  360 of 3260 completed
# $2412.T: possibly delisted; No price data found  (1d 2024-07-10 00:00:00 -> 2024-07-11 00:00:00)
# [********              17%%                      ]  566 of 3260 completed
# $9783.T: possibly delisted; No price data found  (1d 2024-07-10 00:00:00 -> 2024-07-11 00:00:00)
# [*************         28%%                      ]  910 of 3260 completed
# $9995.T: possibly delisted; No price data found  (1d 2024-07-10 00:00:00 -> 2024-07-11 00:00:00)
# $2812.T: possibly delisted; No price data found  (1d 2024-07-10 00:00:00 -> 2024-07-11 00:00:00)
# [****************      34%%                      ]  1107 of 3260 completedException in thread Thread-1112 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 873, in animate
#     print('\r' + str(self), end='', file=_sys.stderr)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 694, in write
#     self._schedule_flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 590, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Thread(Thread-1112 (_run_via_pool), started 29431099392)>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self._invoke_excepthook(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1389, in invoke_excepthook
#     local_print("Exception in threading.excepthook:",
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1117 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Thread(Thread-1117 (_run_via_pool), started 29515231232)>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self._invoke_excepthook(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1389, in invoke_excepthook
#     local_print("Exception in threading.excepthook:",
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1114 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Thread(Thread-1114 (_run_via_pool), started 29464752128)>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self._invoke_excepthook(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1389, in invoke_excepthook
#     local_print("Exception in threading.excepthook:",
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1116 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 873, in animate
#     print('\r' + str(self), end='', file=_sys.stderr)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 694, in write
#     self._schedule_flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 590, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Thread(Thread-1116 (_run_via_pool), started 29498404864)>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self._invoke_excepthook(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1389, in invoke_excepthook
#     local_print("Exception in threading.excepthook:",
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1121 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1119 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1118 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1115 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 873, in animate
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     print('\r' + str(self), end='', file=_sys.stderr)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 694, in write
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 873, in animate
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     print('\r' + str(self), end='', file=_sys.stderr)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 694, in write
#     self._schedule_flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 590, in _schedule_flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1120 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
# zmq.error.ZMQError: Too many open files
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Thread(Thread-1121 (_run_via_pool), started 29582536704)>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1030, in _bootstrap
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1122 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
#     self._schedule_flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 590, in _schedule_flush
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     self._bootstrap_inner()
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     self._invoke_excepthook(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1389, in invoke_excepthook
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Thread(Thread-1118 (_run_via_pool), started 29532057600)>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1030, in _bootstrap
#     local_print("Exception in threading.excepthook:",
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
# zmq.error.ZMQError: Too many open files
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Thread(Thread-1119 (_run_via_pool), started 29548883968)>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
# zmq.error.ZMQError: Too many open files
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Thread(Thread-1115 (_run_via_pool), started 29481578496)>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1030, in _bootstrap
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 873, in animate
#     self._bootstrap_inner()
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._bootstrap_inner()
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self._invoke_excepthook(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1389, in invoke_excepthook
#       File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#       File "/opt/miniconda3/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     self._invoke_excepthook(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1389, in invoke_excepthook
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#       File "/opt/miniconda3/lib/python3.12/threading.py", line 1389, in invoke_excepthook
#     local_print("Exception in threading.excepthook:",
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1123 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 694, in write
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#       File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     self._schedule_flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 590, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#       File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#       File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
# zmq.error.ZMQError: Too many open files
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Thread(Thread-1122 (_run_via_pool), started 29599363072)>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1030, in _bootstrap
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#       File "/opt/miniconda3/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Thread(Thread-1120 (_run_via_pool), started 29565710336)>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1030, in _bootstrap
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
# zmq.error.ZMQError: Too many open files
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     self._invoke_excepthook(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1389, in invoke_excepthook
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
# zmq.error    self._bootstrap_inner()
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     self._invoke_excepthook(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1389, in invoke_excepthook
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     local_print("Exception in threading.excepthook:",
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1124 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
#     local_print("Exception in threading.excepthook:",
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
# zmq.error.ZMQError: Too many open files
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#       File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
# ...
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
# [****************      34%%                      ]  1109 of 3260 completedException in thread Thread-1168 (_run_via_pool):
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 142, in _event_pipe
#       File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
# zmq.error.ZMQError: Too many open files
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     self.run()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
# zmq.error.ZMQError: Too many open files
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     _threading_Thread_run(self)
#   File "/opt/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/lib/python3.12/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     return callee(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/multi.py", line 258, in _download_one_threaded
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#         self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     shared._PROGRESS_BAR.animate()
#   File "/opt/miniconda3/lib/python3.12/site-packages/yfinance/utils.py", line 874, in animate
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
# self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     _sys.stderr.flush()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
# zmq.error.ZMQError: Too many open files
#     self.pub_thread.schedule(self._flush)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 146, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/context.py", line 362, in socket
# zmq.error.ZMQError: Too many open files
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# zmq.error.ZMQError: Too many open files
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     super().__init__(
#   File "zmq/backend/cython/socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# zmq.error.ZMQError: Too many open files
# [*******************   40%%                      ]  1301 of 3260 completed
# $6556.T: possibly delisted; No price data found  (1d 2024-07-10 00:00:00 -> 2024-07-11 00:00:00)
# [**********************56%%*                     ]  1823 of 3260 completed
# $2427.T: possibly delisted; No price data found  (1d 2024-07-10 00:00:00 -> 2024-07-11 00:00:00)
# [*********************100%%**********************]  3260 of 3260 completed
#
# 13 Failed downloads:
# ['4636.T', '1971.T', '7338.T', '8925.T', '9977.T']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ['4185.T', '7816.T', '2412.T', '9783.T', '9995.T', '2812.T', '6556.T', '2427.T']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2024-07-10 00:00:00 -> 2024-07-11 00:00:00)')

# %%
from tqdm import tqdm

# %%
df_master_yf = pd.DataFrame(columns=["Code", "previousClose", "trailingPE", "volume", "marketCap", "fiftyTwoWeekLow", "fiftyTwoWeekHigh", "revenuePerShare"])
columns_yf = ["Code", "previousClose", "trailingPE", "volume", "marketCap", "fiftyTwoWeekLow", "fiftyTwoWeekHigh", "revenuePerShare"]
listInfo = ["previousClose", "trailingPE", "volume", "marketCap", "fiftyTwoWeekLow", "fiftyTwoWeekHigh", "revenuePerShare"]

for tk in tqdm(ticker): 
    stock = yf.Ticker(tk)
    data = []
    data.append(tk)
    for info in listInfo:
        try:
            data.append(stock.info[info])
        except:
            data.append("0")     
            
    df_yf_temp = pd.DataFrame(data=[data], columns=columns_yf)
    df_master_yf = pd.concat([df_master_yf, df_yf_temp], ignore_index=True)
#df_yf.head()
# Out:
#   0%|                                                                                                            | 0/3258 [00:00<?, ?it/s]/var/folders/4d/73_4mvkd4nsc69k9dpv182fr0000gn/T/ipykernel_50147/2638317538.py:16: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_master_yf = pd.concat([df_master_yf, df_yf_temp], ignore_index=True)
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████▍| 3240/3258 [06:01<00:02,  8.74it/s]404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/9977.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=9977.T&crumb=VwK2CDhFwWX
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 3258/3258 [06:04<00:00,  8.95it/s]

# %%
df_master_yf.shape
# Out:
# (3258, 8)

# %%
df_master_yf["MarketCodeCleansed"] = df_master_yf["Code"]

# %%
df_master = pd.merge(df, df_master_yf, on='MarketCodeCleansed')

# %%
df_master = df_master.drop('Code_y', axis=1)

# %%
df_master.dropna(subset=["trailingPE", "marketCap"], inplace=True)
df_master["trailingPE"] = pd.to_numeric(df_master["trailingPE"], errors='coerce')
df_master["marketCap"] = pd.to_numeric(df_master["marketCap"], errors='coerce')

# %%
df_short_list = df_master[(df_master["trailingPE"] < 10) & (df_master["marketCap"] < 50000000000) & (df_master["trailingPE"] > 0.5)].sort_values(by=['trailingPE'])

# %%
df_short_list.head()
# Out:
#             Date Code_x   CompanyName             CompanyNameEnglish  \
# 2459  2024-04-26  78370       アールシーコア              R.C.CORE CO.,LTD.
# 1433  2024-04-26  54760       日本高周波鋼業  Nippon Koshuha Steel Co.,Ltd.
# 1363  2024-04-26  52100        日本山村硝子  Nihon Yamamura Glass Co.,Ltd.
# 2557  2024-04-26  79970       くろがね工作所        Kurogane Kosakusho Ltd.
# 3107  2024-04-26  96580  ビジネスブレイン太田昭和  BUSINESS BRAIN SHOWA・OTA INC.
#
#      Sector17Code Sector17CodeName Sector33Code Sector33CodeName  \
# 2459           10     情報通信・サービスその他         3800            その他製品
# 1433            7            鉄鋼・非鉄         3450               鉄鋼
# 1363            3            建設・資材         3400         ガラス･土石製品
# 2557           10     情報通信・サービスその他         3800            その他製品
# 3107           10     情報通信・サービスその他         5250           情報･通信業
#
#       ScaleCategory MarketCode MarketCodeName MarketCodeCleansed  \
# 2459              -       0112         スタンダード             7837.T
# 1433  TOPIX Small 2       0112         スタンダード             5476.T
# 1363  TOPIX Small 2       0112         スタンダード             5210.T
# 2557              -       0112         スタンダード             7997.T
# 3107  TOPIX Small 2       0111           プライム             9658.T
#
#      previousClose  trailingPE volume    marketCap fiftyTwoWeekLow  \
# 2459         476.0    0.948944   2200   1950471936           390.0
# 1433         478.0    1.050532  21500   6946185728           349.0
# 1363        1553.0    1.280898  31500  15704825856          1066.0
# 2557        1056.0    1.768044  68900   1698319744           744.0
# 3107        2234.0    1.814885  24800  25736314880          1928.0
#
#      fiftyTwoWeekHigh revenuePerShare
# 2459            537.0        2870.422
# 1433            760.0        2498.567
# 1363           2120.0        7136.813
# 2557           1919.0        4340.062
# 3107           2318.0        2961.998

# %%
import pandas as pd
from sqlalchemy import create_engine, Column, String, Integer, MetaData, Table
from sqlalchemy.dialects.postgresql import NUMERIC, BIGINT
import psycopg2

# Define the database connection string (update with your PostgreSQL details)
DATABASE_URI = 'postgresql+psycopg2://root:root@localhost:5433/financial_data'

# Create an engine and metadata object
engine = create_engine(DATABASE_URI)
metadata = MetaData()

# Define the table schema
t_short_list = Table(
    't_short_list', metadata,
    Column('Date', String(50)),
    Column('Code_x', String(50)),
    Column('CompanyName', String(100)),
    Column('CompanyNameEnglish', String(200)),
    Column('Sector17Code', String(10)),
    Column('Sector17CodeName', String(200)),
    Column('Sector33Code', String(10)),
    Column('Sector33CodeName', String(200)),
    Column('ScaleCategory', String(50)),
    Column('MarketCode', String(10)),
    Column('MarketCodeName', String(50)),
    Column('MarketCodeCleansed', String(50)),
    Column('previousClose', Integer),
    Column('trailingPE', NUMERIC(18, 10)),
    Column('volume', Integer),
    Column('marketCap', BIGINT),
    Column('fiftyTwoWeekLow', Integer),
    Column('fiftyTwoWeekHigh', Integer),
    Column('revenuePerShare', NUMERIC(18, 10))
    
)

# Create the table in the database
metadata.create_all(engine)

# %%
df_short_list.to_sql('t_short_list', con=engine, if_exists='append', index=False)
# Out:
# 569
